# %% [markdown]
# Python_End_Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('myexcel.csv')
_dataset
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# __PRE-PROCESSING: REPLACING THE INCORRECT "HEIGHT" DATA WITH CORRECT DATA__

# %%
dataset ["Height"]= np.random.uniform(150,180,size=len(dataset))
dataset
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  150.644346     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  174.514162     235
# 2     John Holland  Boston Celtics      30       SG   27  169.206756     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  171.640772     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  169.646489     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  158.432224     203
# 454      Raul Neto       Utah Jazz      25       PG   24  162.391119     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  175.242853     256
# 456    Jeff Withey       Utah Jazz      24        C   26  154.288677     231
# 457       Priyanka       Utah Jazz      34        C   25  164.383419     231
#
#                College     Salary
# ...

# %% [markdown]
# Q1. How many are there in each Team and the percentage splitting with respect to the total employees?

# %%
counts = dataset["Team"].value_counts()
percentage = (counts / len(dataset)) *100
total_employees = pd.DataFrame({"Count": counts, "Percentage": percentage})
total_employees
# Out:
#                         Count  Percentage
# Team
# New Orleans Pelicans       19    4.148472
# Memphis Grizzlies          18    3.930131
# Utah Jazz                  16    3.493450
# Milwaukee Bucks            16    3.493450
# New York Knicks            16    3.493450
# Boston Celtics             15    3.275109
# Los Angeles Clippers       15    3.275109
# Los Angeles Lakers         15    3.275109
# Phoenix Suns               15    3.275109
# Sacramento Kings           15    3.275109
# Brooklyn Nets              15    3.275109
# Philadelphia 76ers         15    3.275109
# Toronto Raptors            15    3.275109
# Golden State Warriors      15    3.275109
# Indiana Pacers             15    3.275109
# Detroit Pistons            15    3.275109
# Cleveland Cavaliers        15    3.275109
# Chicago Bulls              15    3.275109
# Houston Rockets            15    3.275109
# San Antonio Spurs          15    3.275109
# Atlanta Hawks              15    3.275109
# ...

# %%
#Q2. Segregate the employees w.r.t different positions.

positions = dataset["Position"].value_counts()
positions
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
# Q3. Find from which age group most of the employees belong to.

# %%
age = pd.cut(dataset['Age'], bins=[20, 30, 40, 50, 60, 70])
age_group = age.value_counts()
age_group
# Out:
# Age
# (20, 30]    346
# (30, 40]     91
# (40, 50]      0
# (50, 60]      0
# (60, 70]      0
# Name: count, dtype: int64

# %%
#Q4. Finding out under which team and position spending in terms of salary is high?
high_salary = dataset.groupby (["Team", "Position"]) ["Salary"].sum().idxmax()
high_salary
# Out:
# ('Los Angeles Lakers', 'SF')

# %%
#Q5. Find if there is any correlation between age and salary , represent it visually.
plt.figure (figure = (8,6))
sns.scatterplot(x = "Age", y = "Salary", data = dataset )
plt.title ("CORRELATION BETWEEN AGE & SALARY")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.show()
